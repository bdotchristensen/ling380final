# %%
import pandas as pd
import pickle

# %%
with open('./cases.pkl', 'rb') as f:
    data = pickle.load(f)
    
data
# Out:
# {'nominative': ['rok',
#   'člověk',
#   'den',
#   'doba',
#   'dítě',
#   'život',
#   'místo',
#   'ruka',
#   'práce',
#   'strana',
#   'svět',
#   'země',
#   'čas',
#   'žena',
#   'muž',
#   'případ',
#   'hlava',
#   'oko',
#   'město',
#   'cesta',
#   'dům',
#   'věc',
#   'voda',
#   'společnost',
#   'část',
#   'chvíle',
#   'systém',
#   'hodina',
#   'slovo',
#   'problém',
#   'cena',
#   'Praha',
#   'řada',
#   'škola',
#   'firma',
#   'konec',
#   'koruna',
#   'pohled',
#   'způsob',
#   'dveře',
#   'možnost',
#   'oblast',
#   'milión',
#   'peníze',
#   'tělo',
#   'situace',
#   'stát',
#   'otázka',
#   'kniha',
#   'skupina',
#   'pan',
#   'otec',
#   'tisíc',
#   'rodina',
#   'měsíc',
#   'matka',
#   'změna',
#   'jméno',
#   'projekt',
#   'týden',
#   'auto',
#   'tvář',
#   'výsledek',
#   'většina',
#   'noc',
#   'síla',
#   'vztah',
#   'noha',
#   'program',
#   'hlas',
#   'hra',
#   'film',
#   'minuta',
#   'informace',
#   'prostor',
# ...

# %%
czech_cases = pd.DataFrame(data)
czech_cases
# Out:
#      nominative    genitive      dative  accusative    vocative    locative  \
# 0           rok        roka        roku         rok        roku        roku
# 1        člověk     člověka     člověku     člověka     člověče     člověku
# 2           den         dne         dni         den         dne         dni
# 3          doba        doby        době        dobu        dobo        době
# 4          dítě      dítěte      dítěti        dítě        dítě      dítěti
# ...         ...         ...         ...         ...         ...         ...
# 1569  platforma   platformy   platformě   platformu   platformo   platformě
# 1570  skladatel  skladatele  skladateli  skladatele  skladateli  skladateli
# 1571     náznak     náznaku     náznaku      náznak     náznaku     náznaku
# 1572   eurozóna    eurozóny    eurozóně    eurozónu    eurozóno    eurozóně
# 1573       práh       prahu       prahu        práh       prahu       prahu
#
#      instrumental
# 0           rokem
# ...

# %%
czech_cases.to_csv('./czech_nouns_cased.csv')
